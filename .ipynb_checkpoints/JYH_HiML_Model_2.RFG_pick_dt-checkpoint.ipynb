# %% [markdown]
# # JON'S HiML Competition RFG_Log Model_picker (v 2.RFG)
# # (Decision Tree Version)
# ## Make Date: 04/13/18
#
# 1. This ML model was built using scikit's RandomForestRegressor model.
# 1. Automatically find the best combination of input parameters using the combo-picker function
# 1. Let's implement log transform on the quantities to improve score.

# %%
#Some initialization procedures:
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# load in data files
# FILE_DIR = '../input/hawaiiml-data'
# for f in os.listdir(FILE_DIR):
#     print('{0:<30}{1:0.2f}MB'.format(f, 1e-6*os.path.getsize(f'{FILE_DIR}/{f}')))
df_train = pd.read_csv(f'train_rm.csv', encoding='ISO-8859-1') #write training data to dataframe
df_test = pd.read_csv(f'test_rm.csv', encoding='ISO-8859-1') # Read the test data

#define the error function:
def rmsle(y_true, y_pred):
    return np.sqrt(np.mean((np.log1p(y_true) - np.log1p(y_pred))**2))

# %% [markdown]
# # Build Features

# %%
# #convert date strings to datatime datatypes:
# df_train['date'] = pd.to_datetime(df_train['date'])
# df_test['date'] = pd.to_datetime(df_test['date'])

# df_train = df_train.assign(day_of_week = df_train.date.dt.dayofweek)
# df_test = df_test.assign(day_of_week = df_test.date.dt.dayofweek)

# %%
# df_train = df_train.assign(is_day0To2 = 0)
# df_train['is_day0To2'] = 0
# df_train.loc[(df_train['day_of_week'] < 3),['is_day0To2']]  = 1

# df_train = df_train.assign(is_day3 = 0)
# df_train['is_day3'] = 0
# df_train.loc[(df_train['day_of_week'] == 3),['is_day3']]  = 1

# df_train = df_train.assign(is_day4 = 0)
# df_train['is_day4'] = 0
# df_train.loc[(df_train['day_of_week'] == 4),['is_day4']]  = 1

# df_train = df_train.assign(is_day6 = 0)
# df_train['is_day6'] = 0
# df_train.loc[(df_train['day_of_week'] == 6),['is_day6']]  = 1

# %%
df_train = df_train.loc[(df_train['unit_price'] >= 0) & (df_train['unit_price'] < 10000) ]
df_train = df_train.assign(unit_price_log1p = np.log1p(df_train.unit_price))
df_test = df_test.assign(unit_price_log1p = np.log1p(df_test.unit_price))

# %%
df_train = df_train.assign(customer_7 = 0)
df_train.loc[(df_train['customer_id'] == 7),['customer_7']]  = 1

df_train = df_train.assign(is_uk = 0)
df_train.loc[(df_train['country'] == "united kingdom"),['is_uk']]  = 1

# %%
df_train.head()
# Out:
#        id        date      time  invoice_id  stock_id  customer_id  \
# 0  330477   8/30/2011  12:26:00         357       198            7
# 1  113814   11/1/2011  14:54:00        6757      2747          410
# 2   51510   7/11/2011  16:21:00          52       755            7
# 3  257784  10/11/2011  14:52:00        3642      1942         1722
# 4  431803  11/14/2011  14:59:00        2105        39         1159
#
#           country                        description  unit_price  quantity  \
# 0  united kingdom      french blue metal door sign 3        2.46         1
# 1  united kingdom  paper lantern 9 point deluxe star        6.65         4
# 2  united kingdom              fruit salad bag charm        2.46         1
# 3          france         set of 10 led dolly lights        6.25         2
# 4  united kingdom             glitter christmas star        0.39         5
#
#    ...    max_price  min_price median_price median_diff  mean_diff  min_diff  \
# 0  ...         2.95       0.00         1.25        1.21   0.870397      2.46
# 1  ...         6.65       6.65         6.65        0.00   0.000000      0.00
# 2  ...         2.51       1.69         2.46        0.00   0.052821      0.77
# 3  ...        12.46       5.39         6.25        0.00  -0.245805      0.86
# 4  ...         1.66       0.39         0.39        0.00  -0.160865      0.00
#
#    max_diff  unit_price_log1p  customer_7  is_uk
# 0      0.49          1.241269           1      1
# 1      0.00          2.034706           0      1
# 2      0.05          1.241269           1      1
# 3      6.21          1.981001           0      0
# 4      1.27          0.329304           0      1
#
# [5 rows x 39 columns]

# %%
# df_train = df_train.assign(uplog1p_quant1 = 0)
# df_train.loc[(df_train['unit_price_log1p'] < 6.47774129795256),['uplog1p_quant1']]  = 1
# df_test = df_test.assign(uplog1p_quant1 = 0)
# df_test.loc[(df_test['unit_price_log1p'] < 6.47774129795256),['uplog1p_quant1']]  = 1

# %%
# df_train['time'] = pd.to_datetime(df_train['time'])
# df_test['time'] = pd.to_datetime(df_test['time'])
# df_train = df_train.assign(hr = df_train.time.dt.hour)
# df_test = df_test.assign(hr = df_test.time.dt.hour)

# %%
# df_train = df_train.assign(invoice_id_log1p = np.log1p(df_train.invoice_id))
# df_test = df_test.assign(invoice_id_log1p = np.log1p(df_test.invoice_id))

# %% [markdown]
# # Define Training Target Data:
# 1. We want to predict the quantity data field.
# 1. By convention, we define this target as 'y'.
# 1. From model 2.02, we know that doing a log transform on the tartget reduces skewness and improves score.

# %%
y = df_train.quantity
logy = np.log1p(df_train.quantity) #take log of quantities

# %% [markdown]
# # Define ML Predictors
# build a function to go through each combination of predictors

# %% [markdown]
# ### Here is the list of columns we can choose predictors from.

# %%
print('Column Names & Data Types: \n', df_train.dtypes)
# Out:
# Column Names & Data Types:
#  id                    int64
# date                 object
# time                 object
# invoice_id            int64
# stock_id              int64
# customer_id           int64
# country              object
# description          object
# unit_price          float64
# quantity              int64
# UK                    int64
# log_quantity        float64
# date2                object
# time2                object
# hour                  int64
# desc_set              int64
# desc_bag              int64
# desc_red              int64
# desc_heart            int64
# desc_retrospot        int64
# desc_vintage          int64
# desc_design           int64
# desc_pink             int64
# desc_christmas        int64
# desc_box              int64
# morning               int64
# afternoon             int64
# evening               int64
# mean_price          float64
# max_price           float64
# min_price           float64
# median_price        float64
# median_diff         float64
# mean_diff           float64
# min_diff            float64
# max_diff            float64
# unit_price_log1p    float64
# customer_7            int64
# is_uk                 int64
# dtype: object

# %% [markdown]
# ## Define feature combination picker

# %%
# ls_AllPredictors = ['invoice_id', 'stock_id',
#     'desc_set','desc_bag','desc_red','desc_heart','desc_retrospot','desc_vintage',
#     'desc_design','desc_pink','desc_christmas','desc_box',
#     'morning','afternoon','evening']
                   
ls_AllPredictors = ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id','invoice_id']



# https://stackoverflow.com/questions/464864/how-to-get-all-possible-combinations-of-a-list-s-elements
from itertools import chain, combinations
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)  # allows duplicate elements
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))
#build combos:
ls_PredictorCombos = [list(combo[1]) for combo in enumerate(powerset(ls_AllPredictors), 1)]
#Define combo getting function:
def GetX(comboID, adf_train):
    #get X values in adf_train for the given list of predictors
    return adf_train[ls_PredictorCombos[comboID]]

# %% [markdown]
# # Implement Random Forest Regressor Model on Each Predictor Combo
# ## Define Some Helper Functions

# %%
def Run_RFG(SeedVal, X, logy):
    #fit, predict, and then evaluate a model using passed in values (e.g. training set)
    #return back RMSLE value and trained model

    myModel = DecisionTreeRegressor()

    train_X, val_X, train_y, val_y = train_test_split(X, logy,random_state = SeedVal) #split training data into a test and train part
    myModel.fit(train_X, train_y)
    predicted_vals = np.expm1(myModel.predict(val_X)) #transform predicted values from log to "normal" Y value
    return rmsle(np.expm1(val_y), predicted_vals), myModel #include transform of val_Y values from log to "normal" Y value

# %%
def FindBestCombo_Model(adf_train, logy):
    #iteratively search for best parameter combinations to match X values in adf_train with logy
    #return best combo, error results of each model, training error, and model
    MinErr = 100000000
    df_Track = pd.DataFrame()
    for comboID in range(1,len(ls_PredictorCombos)):
        print('Eval combo:', ls_PredictorCombos[comboID])
        SeedVal = 0
        X = GetX(comboID, adf_train)
        TrainErr,myModel = Run_RFG(SeedVal,X,logy)
        df2 = pd.DataFrame([[comboID, TrainErr, ','.join(ls_PredictorCombos[comboID])]],columns=['ComboID','err','Preds'])
        if df_Track.shape[0] >0:
            df_Track = pd.concat([df2, df_Track])
        else:
            df_Track = df2.copy(deep = True)
        if TrainErr < MinErr:
            MinErr = TrainErr
    #         BestSeedVal = SeedVal
            bestComboID = comboID
            print ('Best Combo: ', comboID, ' Params: ', ls_PredictorCombos[comboID], ' Err: ', TrainErr)
    #train with best combo:
    X = GetX(bestComboID, adf_train)
    TrainErr,myModel = Run_RFG(0,X,logy)
    print ('fin')
    return ls_PredictorCombos[bestComboID], df_Track, TrainErr, myModel

# %% [markdown]
# ### Build Customer 7 and Everyone Else Models:
# 1. Find Best Predictors
# 1. Define Separate Models

# %%
TrainErr,myModel = Run_RFG(0,df_train[['customer_id', 'unit_price_log1p', 'median_diff'] ],logy)
TrainErr
# Out:
# 0.58538817468583026

# %%
TrainErr,myModel = Run_RFG(0,df_train[['customer_id', 'unit_price_log1p', 'median_diff',"desc_bag","evening"] ],logy)
TrainErr
# Out:
# 0.5868190657314255

# %%
TrainErr,myModel = Run_RFG(0,df_train[['customer_id', 'unit_price_log1p', 'median_diff', 'is_uk','customer_7'] ],logy)
TrainErr
# Out:
# 0.57864912652828315

# %%
TrainErr,myModel = Run_RFG(0,df_train[['customer_id', 'unit_price_log1p', 'median_diff', 'customer_7','desc_bag'] ],logy)
TrainErr
# Out:
# 0.58497953921804358

# %%
TrainErr,myModel = Run_RFG(0,df_train[['customer_id', 'unit_price_log1p', 'median_diff', 'customer_7','desc_bag','evening'] ],logy)
TrainErr
# Out:
# 0.58677837432293722

# %%
ls_mypredictors, df_Track, TrainErr, myModel = FindBestCombo_Model(df_train, logy)
# Out:
# Eval combo: ['customer_id']
# Best Combo:  1  Params:  ['customer_id']  Err:  0.702305575779
# Eval combo: ['unit_price_log1p']
# Eval combo: ['median_diff']
# Eval combo: ['desc_bag']
# Eval combo: ['desc_box']
# Eval combo: ['evening']
# Eval combo: ['stock_id']
# Eval combo: ['invoice_id']
# Best Combo:  8  Params:  ['invoice_id']  Err:  0.6834482337
# Eval combo: ['customer_id', 'unit_price_log1p']
# Best Combo:  9  Params:  ['customer_id', 'unit_price_log1p']  Err:  0.601746174119
# Eval combo: ['customer_id', 'median_diff']
# Eval combo: ['customer_id', 'desc_bag']
# Eval combo: ['customer_id', 'desc_box']
# Eval combo: ['customer_id', 'evening']
# Eval combo: ['customer_id', 'stock_id']
# Eval combo: ['customer_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff']
# Eval combo: ['unit_price_log1p', 'desc_bag']
# Eval combo: ['unit_price_log1p', 'desc_box']
# Eval combo: ['unit_price_log1p', 'evening']
# Eval combo: ['unit_price_log1p', 'stock_id']
# Eval combo: ['unit_price_log1p', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag']
# Eval combo: ['median_diff', 'desc_box']
# Eval combo: ['median_diff', 'evening']
# Eval combo: ['median_diff', 'stock_id']
# Eval combo: ['median_diff', 'invoice_id']
# Eval combo: ['desc_bag', 'desc_box']
# Eval combo: ['desc_bag', 'evening']
# Eval combo: ['desc_bag', 'stock_id']
# Eval combo: ['desc_bag', 'invoice_id']
# Eval combo: ['desc_box', 'evening']
# Eval combo: ['desc_box', 'stock_id']
# Eval combo: ['desc_box', 'invoice_id']
# Eval combo: ['evening', 'stock_id']
# Eval combo: ['evening', 'invoice_id']
# Eval combo: ['stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff']
# Best Combo:  37  Params:  ['customer_id', 'unit_price_log1p', 'median_diff']  Err:  0.584897893347
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_box']
# Eval combo: ['customer_id', 'unit_price_log1p', 'evening']
# Eval combo: ['customer_id', 'unit_price_log1p', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag']
# Eval combo: ['customer_id', 'median_diff', 'desc_box']
# Eval combo: ['customer_id', 'median_diff', 'evening']
# Eval combo: ['customer_id', 'median_diff', 'stock_id']
# Eval combo: ['customer_id', 'median_diff', 'invoice_id']
# Eval combo: ['customer_id', 'desc_bag', 'desc_box']
# Eval combo: ['customer_id', 'desc_bag', 'evening']
# Eval combo: ['customer_id', 'desc_bag', 'stock_id']
# Eval combo: ['customer_id', 'desc_bag', 'invoice_id']
# Eval combo: ['customer_id', 'desc_box', 'evening']
# Eval combo: ['customer_id', 'desc_box', 'stock_id']
# Eval combo: ['customer_id', 'desc_box', 'invoice_id']
# Eval combo: ['customer_id', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_box']
# Eval combo: ['unit_price_log1p', 'median_diff', 'evening']
# Eval combo: ['unit_price_log1p', 'median_diff', 'stock_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'desc_box']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'evening']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'stock_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_box', 'evening']
# Eval combo: ['unit_price_log1p', 'desc_box', 'stock_id']
# Eval combo: ['unit_price_log1p', 'desc_box', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'evening', 'stock_id']
# Eval combo: ['unit_price_log1p', 'evening', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'stock_id', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag', 'desc_box']
# Eval combo: ['median_diff', 'desc_bag', 'evening']
# Eval combo: ['median_diff', 'desc_bag', 'stock_id']
# Eval combo: ['median_diff', 'desc_bag', 'invoice_id']
# Eval combo: ['median_diff', 'desc_box', 'evening']
# Eval combo: ['median_diff', 'desc_box', 'stock_id']
# Eval combo: ['median_diff', 'desc_box', 'invoice_id']
# Eval combo: ['median_diff', 'evening', 'stock_id']
# Eval combo: ['median_diff', 'evening', 'invoice_id']
# Eval combo: ['median_diff', 'stock_id', 'invoice_id']
# Eval combo: ['desc_bag', 'desc_box', 'evening']
# Eval combo: ['desc_bag', 'desc_box', 'stock_id']
# Eval combo: ['desc_bag', 'desc_box', 'invoice_id']
# Eval combo: ['desc_bag', 'evening', 'stock_id']
# Eval combo: ['desc_bag', 'evening', 'invoice_id']
# Eval combo: ['desc_bag', 'stock_id', 'invoice_id']
# Eval combo: ['desc_box', 'evening', 'stock_id']
# Eval combo: ['desc_box', 'evening', 'invoice_id']
# Eval combo: ['desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_box']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'evening']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'desc_box']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'evening']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_box', 'evening']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_box', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_box', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'desc_box']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'evening']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'stock_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_box', 'evening']
# Eval combo: ['customer_id', 'median_diff', 'desc_box', 'stock_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_box', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'median_diff', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'desc_bag', 'desc_box', 'evening']
# Eval combo: ['customer_id', 'desc_bag', 'desc_box', 'stock_id']
# Eval combo: ['customer_id', 'desc_bag', 'desc_box', 'invoice_id']
# Eval combo: ['customer_id', 'desc_bag', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'desc_bag', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'desc_bag', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'evening']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'stock_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_box', 'evening']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_box', 'stock_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_box', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'evening', 'stock_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'evening', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'desc_box', 'evening']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'desc_box', 'stock_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'desc_box', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'evening', 'stock_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'evening', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['unit_price_log1p', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag', 'desc_box', 'evening']
# Eval combo: ['median_diff', 'desc_bag', 'desc_box', 'stock_id']
# Eval combo: ['median_diff', 'desc_bag', 'desc_box', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag', 'evening', 'stock_id']
# Eval combo: ['median_diff', 'desc_bag', 'evening', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag', 'stock_id', 'invoice_id']
# Eval combo: ['median_diff', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['median_diff', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['median_diff', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['median_diff', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['desc_bag', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['desc_bag', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['desc_bag', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['desc_bag', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'evening']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_box', 'evening']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_box', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_box', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'desc_box', 'evening']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'desc_box', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'desc_box', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'desc_box', 'evening']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'desc_box', 'stock_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'desc_box', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'desc_bag', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'desc_bag', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'desc_bag', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'desc_bag', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'stock_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'evening', 'stock_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'evening', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['median_diff', 'desc_bag', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['median_diff', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['desc_bag', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'desc_bag', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'desc_bag', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'desc_bag', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# Eval combo: ['customer_id', 'unit_price_log1p', 'median_diff', 'desc_bag', 'desc_box', 'evening', 'stock_id', 'invoice_id']
# fin

# %% [markdown]
# ## Observations

# %%
display(df_Track.sort_values(by=['err']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-7296a83d1906> in <module>()
# ----> 1 display(df_Track.sort_values(by=['err']))
#
# NameError: name 'display' is not defined

# %%
df_Track.sort_values(by=['err'])
# Out:
#     ComboID       err                                              Preds
# 0        37  0.584898           customer_id,unit_price_log1p,median_diff
# 0        93  0.584899  customer_id,unit_price_log1p,median_diff,desc_bag
# 0        95  0.586089   customer_id,unit_price_log1p,median_diff,evening
# 0       164  0.586582  customer_id,unit_price_log1p,median_diff,desc_...
# 0        94  0.586701  customer_id,unit_price_log1p,median_diff,desc_box
# 0       163  0.587524  customer_id,unit_price_log1p,median_diff,desc_...
# 0       167  0.587676  customer_id,unit_price_log1p,median_diff,desc_...
# 0       219  0.588838  customer_id,unit_price_log1p,median_diff,desc_...
# 0         9  0.601746                       customer_id,unit_price_log1p
# 0        40  0.601920               customer_id,unit_price_log1p,evening
# 0        39  0.602673              customer_id,unit_price_log1p,desc_box
# 0       102  0.603712      customer_id,unit_price_log1p,desc_box,evening
# 0        38  0.603965              customer_id,unit_price_log1p,desc_bag
# 0        99  0.604539      customer_id,unit_price_log1p,desc_bag,evening
# 0       173  0.604634  customer_id,unit_price_log1p,desc_bag,desc_box...
# 0        98  0.605023     customer_id,unit_price_log1p,desc_bag,desc_box
# 0        97  0.654664  customer_id,unit_price_log1p,median_diff,invoi...
# 0       171  0.656260  customer_id,unit_price_log1p,median_diff,eveni...
# 0       223  0.656939  customer_id,unit_price_log1p,median_diff,desc_...
# 0       169  0.656944  customer_id,unit_price_log1p,median_diff,desc_...
# 0       166  0.656997  customer_id,unit_price_log1p,median_diff,desc_...
# 0       248  0.659108  customer_id,unit_price_log1p,median_diff,desc_...
# 0       226  0.659391  customer_id,unit_price_log1p,median_diff,desc_...
# 0       221  0.659599  customer_id,unit_price_log1p,median_diff,desc_...
# 0        42  0.675145            customer_id,unit_price_log1p,invoice_id
# 0       106  0.676208    customer_id,unit_price_log1p,evening,invoice_id
# 0       108  0.677702          customer_id,median_diff,desc_bag,desc_box
# 0        43  0.678187                   customer_id,median_diff,desc_bag
# 0       183  0.678274  customer_id,median_diff,desc_bag,desc_box,evening
# 0       109  0.678290           customer_id,median_diff,desc_bag,evening
# ..      ...       ...                                                ...
# 0       126  0.929413           customer_id,desc_box,stock_id,invoice_id
# 0       195  0.929604  customer_id,desc_bag,desc_box,stock_id,invoice_id
# 0       147  0.929700       unit_price_log1p,evening,stock_id,invoice_id
# 0       239  0.929863  customer_id,desc_bag,desc_box,evening,stock_id...
# 0        57  0.930184                    customer_id,stock_id,invoice_id
# 0       197  0.930249   customer_id,desc_box,evening,stock_id,invoice_id
# 0        72  0.931109               unit_price_log1p,stock_id,invoice_id
# 0       216  0.940611   median_diff,desc_bag,evening,stock_id,invoice_id
# 0       246  0.943417  median_diff,desc_bag,desc_box,evening,stock_id...
# 0       215  0.944416  median_diff,desc_bag,desc_box,stock_id,invoice_id
# 0       153  0.944894           median_diff,desc_bag,stock_id,invoice_id
# 0       217  0.945720   median_diff,desc_box,evening,stock_id,invoice_id
# 0       156  0.950282           median_diff,desc_box,stock_id,invoice_id
# 0        82  0.956181                    median_diff,stock_id,invoice_id
# 0       157  0.956288            median_diff,evening,stock_id,invoice_id
# 0        83  0.990275                          desc_bag,desc_box,evening
# 0        28  0.990611                                   desc_bag,evening
# 0        27  0.991085                                  desc_bag,desc_box
# 0         4  0.991427                                           desc_bag
# 0        31  0.991527                                   desc_box,evening
# 0         6  0.991971                                            evening
# 0         5  0.992349                                           desc_box
# 0        92  1.048426                        evening,stock_id,invoice_id
# 0       218  1.050835      desc_bag,desc_box,evening,stock_id,invoice_id
# 0       162  1.053306               desc_box,evening,stock_id,invoice_id
# 0       161  1.053414               desc_bag,evening,stock_id,invoice_id
# 0        36  1.058872                                stock_id,invoice_id
# 0        88  1.058888                       desc_bag,stock_id,invoice_id
# 0       160  1.061540              desc_bag,desc_box,stock_id,invoice_id
# 0        91  1.063261                       desc_box,stock_id,invoice_id
#
# [255 rows x 3 columns]

# %%
print (myModel_7.feature_importances_)
print (myModel_no7.feature_importances_)
# Out:
# [ 0.64557884  0.34338557  0.01103559]
# [ 0.62476342  0.37523658  0.        ]
